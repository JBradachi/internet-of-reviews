# %% [markdown]
# # Análise dos dados obtidos

# %%
# Imports
#  /home/bradachi/Documentos/GitHub/NLP_teste/NLP_ENV/bin/python -m pip install 
import requests
import json
import pprint
import pandas as pd
import lxml
import time
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
import string
import matplotlib.pyplot as plt 
from textblob import TextBlob
# from bertopic import BERTopic
from PIL import Image
import numpy as np
from statsmodels.distributions.empirical_distribution import ECDF
import matplotlib.ticker as mtick
# from LeIA import SentimentIntensityAnalyzer
# from selenium import webdriver
# from webdriver_manager.firefox import GeckoDriverManager 
# from selenium.webdriver.firefox.service import Service 
# from selenium.webdriver.common.action_chains import ActionChains
# from selenium.webdriver.common.keys import Keys
# from selenium.common.exceptions import NoSuchElementException
# Out:
# [nltk_data] Downloading package punkt to /home/bradachi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/bradachi/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/bradachi/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
objects_list = [
"sensores",
"Comedouro Automático",
"guarda roupa inteligente",
"panela inteligente",
"geladeira inteligente",
"cocho inteligente",
"freezer inteligente",
"silo inteligente",
"ar-condicionado inteligente",
"aquecedor inteligente",
"ventilador inteligente",
"Termostato digital",
"fogão inteligente",
"fritadeira a ar inteligente",
"forno inteligente",
"janela inteligente",
"cortina inteligente",
"tomada inteligente",
"aspersor inteligente",
"controlador de irrigação inteligente",
"chuveiro inteligente",
"dispensador de água inteligente",
"filtro de água inteligente",
"estação de tratamento múltipla",
"smartwatch",
"óculos de realidade virtual",
"capacete inteligente",
"anel inteligente",
"colar inteligente",
"cinto inteligente",
"brinco inteligente",
"máscara inteligente",
"monitor de glicose inteligente",
"coleira inteligente",
"bota inteligente",
"fones de ouvido inteligentes",
"prótese inteligente",
"aparelho auditivo inteligente",
"microfone inteligente",
"sonar inteligente",
"cerca elétrica inteligente",
"sensor de perímetro",
"Computador",
"televisão inteligente",
"decodificador inteligente",
"reprodutor de mídia",
"painel de exibição inteligente",
"telemetria inteligente",
"projetor inteligente"
# "totem de autoatendimento",
"inteligente projetor",
"quadro branco inteligente",
# "totem de informações",
"patinete elétrico inteligente",
"robô de colheita",
"braço robótico",
"robô de capina",
"interruptor de luz inteligente",
"Disjuntor automático inteligente",
"secadora de roupas inteligente",
"máquina de lavar roupa inteligente",
"dispensador de comprimidos inteligente",
"lâmpada inteligente",
"RFID",
"Drone",
"impressora 3D inteligente",
"impressora inteligente",
"tapete inteligente",
"caixa de som inteligente",
"espelho inteligente",
"porta inteligente",
"fechadura inteligente",
"câmera inteligente",
"equipamento médico inteligente Kit",
"câmera",
"cafeteira inteligente",
"Google Nest",
"Asistentes pessoais",
"Alexa",
"Echo",
"HomeKit",
"Siri",
"Xiaomi smart home",
"Philips Hue",
"Intelbras smart home",
"Intelbras casa inteligente",
"Positivo Casa Inteligente",
"Multilaser",
"Fitbit",
"LG smart home",
"Tuya"
]
len(objects_list)
# Out:
# 88

# %%
def limpa_por_id(perguntas):
    colunas_para_verificar = perguntas.columns.difference(['id'])
    limpo = perguntas.drop_duplicates(subset=colunas_para_verificar, keep='first')
    return limpo.reset_index(drop=True)

# %%
perguntas = pd.read_csv("perguntas.csv")
perguntas = limpa_por_id(perguntas)
perguntas
# Out:
#                                                 pergunta  \
# 0      Minha cervejeira é VN28AF Termostato sollatek ...
# 1                        Esse termostato tem os 4 pinos?
# 2                        Teria para o modelo VF56DB 220V
# 3                                          Ok ele e 220v
# 4        Bom dia ele serve para o modelo vb15 metal frio
# ...                                                  ...
# 28994                                   Olá é luz quente
# 28995            Precisso da nota fiscal de este produto
# 28996  Muito obrigado pela atenção, E27 que preciso. ...
# 28997       Comprei chegou mas a rosca não é E27 é menor
# 28998                                 tem branco quente?
#
#                                                 resposta           id  \
# 0      Boa tarde, seu termostato saiu de linha o subs...  MLB44743999
# 1      Boa tarde, são 6 pinos porem os que tem função...  MLB44743999
# 2      Boa tarde, seu modelo usa termostato sollatek,...  MLB44743999
# 3                      O termostato do anúncio é bivolt.  MLB44743999
# 4      Bom dia, sim temos programações para expositor...  MLB44743999
# ...                                                  ...          ...
# 28994  Olá Tudo bem? Não, a luz é branco neutro 4000k...  MLB46936892
# 28995  Olá boa tarde! Tudo bem? Claro! Pode nos envia...  MLB46936892
# 28996                Deu certo o Sr. conseguiu utilizar?  MLB46936892
# 28997  Boa noite! Tudo bem? Mas esse modelo não temos...  MLB46936892
# 28998  Olá boa tarde! Tudo bem? Infelizmente não temo...  MLB46936892
#
#              data
# 0      27/11/2025
# 1      26/11/2025
# 2      26/06/2025
# 3      15/05/2025
# 4      16/05/2025
# ...           ...
# 28994  02/09/2025
# 28995  23/06/2025
# 28996  29/05/2025
# 28997  28/05/2025
# 28998  12/05/2025
#
# [28999 rows x 4 columns]

# %%
avaliacoes = pd.read_csv("avaliacoes.csv")
avaliacoes = limpa_por_id(avaliacoes)
avaliacoes
# Out:
#                                                   texto nota           id  \
# 0                                  Excelente produto!!.    5  MLB46241561
# 1                                            Muito bom.    5  MLB48090512
# 2                                    Muito bom produto.    5  MLB48090512
# 3                             Produto bom. Sem retorno.    5  MLB48090512
# 4     Produto confiável e original. Eu mesmo arrumei...    5  MLB29176649
# ...                                                 ...  ...          ...
# 9648  Atendeu super bem para controles de ventilador...    5  MLB50911897
# 9649              Produto excelente e facil instalacao.    5  MLB50911897
# 9650  Simples, rápido e eficiente. Produto muito bom...    5  MLB50911897
# 9651  É elogiado por sua facilidade de configuração ...    5  MLB50911897
# 9652  O produto cumpre o que promete possui um bom a...    5  MLB50911897
#
#               data
# 0     09 out. 2025
# 1     15 out. 2025
# 2     16 out. 2025
# 3     20 nov. 2025
# 4     27 out. 2025
# ...            ...
# 9648  28 nov. 2025
# 9649  01 dez. 2025
# 9650  25 out. 2025
# 9651  20 nov. 2025
# 9652  16 out. 2025
#
# [9653 rows x 4 columns]

# %%
produtos = pd.read_csv("caracteristicas.csv").drop_duplicates()
produtos.to_csv("produtos_limpo.csv",index=False)

# %%
produtos = pd.read_csv("produtos_limpo.csv") #23044
labels = produtos['domain_id'].value_counts().keys().tolist()
list_curve = produtos['domain_id'].value_counts().tolist()
# quant = produtos['domain_id'].value_counts().apply(lambda x: x/23044).tolist()
# acomulador = 0
# new = list()
# for x in quant:
#     new.append(acomulador+x)
#     acomulador = new[-1]
# print(new)

# %%
def get_distribution(df, label):
    soma = df[label].value_counts().sum()
    l = df[label].value_counts().apply(lambda x: x/soma).tolist()
    acomulador = 0
    new = list()
    for x in l:
        new.append(acomulador+x)
        acomulador = new[-1]
    return new

# %%
def create_cdf(
        df:pd.DataFrame, df_label:str, fig_name:str,  
        xlabel:str, title:str="", log:bool=False):
    
    stats = df[df_label].value_counts(normalize=True).to_frame(name='frequencia')
    stats['ccdf'] = stats['frequencia'].cumsum()
    
    stats['cdf'] = 1 - stats['ccdf']


    fig, ax = plt.subplots(figsize=(8, 6))

    ax.plot(df[df_label].value_counts(), stats['cdf'], marker='.', linestyle='-', 
            color="#8f6e2a")# marrom: #8f6e2a verde: #3f4f2d
    
    if log:
        ax.set_xscale('log')
    # else:
    #     # ticks = np.arange(0, df[df_label].value_counts().max(), 2)
    #     # ax.set_xticks(ticks)

    ax.yaxis.set_major_formatter(mtick.PercentFormatter(1.0)) # Eixo Y em %
    if title: ax.set_title(title, fontsize=18)
    ax.yaxis.tick_right()
    ax.yaxis.set_label_position('right')
    ax.set_xlabel(xlabel, fontsize=16)
    ax.set_ylabel('% Acumulada', fontsize=16)
    ax.grid(True, which="both", ls="-", alpha=0.3)

    fig.savefig(fig_name)
    # ax.axhline(y=0.8, color='r', linestyle='--', alpha=0.5)
    # ax.text(stats['rank'].min(), 0.81, '80% do volume', color='r', fontsize=9)

    plt.tight_layout()
    plt.show()

# %%
produtos = pd.read_csv("produtos_limpo.csv")
id_domain = produtos[["id", "domain_id"]]

avaliacao_domain = pd.merge(avaliacoes, id_domain, on='id', how='inner')

# frequencia = avaliacao_domain['id'].value_counts()

# create_cdf(avaliacao_domain, 'id', 'avaliação_normal', 'Quantidade de Avaliações')
create_cdf(avaliacao_domain, 'id', 'avaliação_log', 'Quantidade de Avaliações', log=True)

# %%
perguntas_domain = pd.merge(perguntas, id_domain, on='id', how='inner')

# create_cdf(perguntas_domain, 'id', 'perguntas_normal', 'Quantidade de perguntas')
create_cdf(perguntas_domain, 'id', 'perguntas_log', 'Quantidade de Perguntas',log=True)

# %%
smartObjects = pd.read_csv("contexto.csv").drop_duplicates()
smartObjects.to_csv("contexto_limpo.csv", index=False)

# %%
smartObjects = pd.read_csv("contexto_limpo.csv")

wifiObjects = smartObjects[smartObjects["Context_Id"] == "WITH_WI_FI"]
bltObjects = smartObjects[smartObjects["Context_Id"] == "WITH_BLUETOOTH"]
connTypesObjects = smartObjects[smartObjects["Context_Id"] == "CONNECTION_TYPES"]
connObjects = smartObjects[smartObjects["Context_Id"] == "CONNECTIVITY"]

smartObjects = pd.concat([wifiObjects, bltObjects])

smartObjects = smartObjects[smartObjects["value_name"] == "Sim"]

smartObjects = pd.concat([smartObjects, connTypesObjects, connObjects])

smartObjects = smartObjects["id"].drop_duplicates().reset_index(drop=True)
smartObjects = list(smartObjects)
smartObjects
# Out:
# ['MLB36333923',
#  'MLB36139109',
#  'MLB21345002',
#  'MLB38703841',
#  'MLB36398531',
#  'MLB54448099',
#  'MLB48677687',
#  'MLB19552926',
#  'MLB27839322',
#  'MLB28002506',
#  'MLB56994543',
#  'MLB29568434',
#  'MLB26446377',
#  'MLB38750127',
#  'MLB54236783',
#  'MLB41626835',
#  'MLB24455199',
#  'MLB57356995',
#  'MLB27985244',
#  'MLB28682642',
#  'MLB43616708',
#  'MLB27769043',
#  'MLB34345595',
#  'MLB28754492',
#  'MLB61666608',
#  'MLB40002972',
#  'MLB25735509',
#  'MLB41799760',
#  'MLB39171159',
#  'MLB28037061',
#  'MLB28834431',
#  'MLB51925280',
#  'MLB35985980',
#  'MLB23222747',
#  'MLB45867674',
#  'MLB36956947',
#  'MLB27238649',
#  'MLB20049271',
#  'MLB20545758',
#  'MLB29417181',
#  'MLB26085789',
#  'MLB42639627',
#  'MLB39983380',
#  'MLB20662835',
#  'MLB26051587',
#  'MLB52139663',
#  'MLB22145672',
#  'MLB24198079',
#  'MLB37791461',
#  'MLB24228530',
#  'MLB58376900',
#  'MLB36411103',
#  'MLB36034704',
#  'MLB23942605',
#  'MLB44845954',
#  'MLB22031377',
#  'MLB40543976',
#  'MLB48710929',
#  'MLB60176792',
#  'MLB48848053',
#  'MLB38347793',
#  'MLB38264333',
#  'MLB38532151',
#  'MLB47457839',
#  'MLB36860729',
#  'MLB46028773',
#  'MLB62124393',
#  'MLB36440860',
#  'MLB60004306',
#  'MLB38607495',
#  'MLB32041012',
#  'MLB47385600',
#  'MLB23494147',
#  'MLB35472889',
#  'MLB46164967',
#  'MLB53366520',
#  'MLB60025940',
#  'MLB36389764',
#  'MLB44846545',
#  'MLB49322713',
#  'MLB48199444',
#  'MLB38182044',
#  'MLB38530575',
#  'MLB41961651',
#  'MLB48058975',
#  'MLB42137736',
#  'MLB62221449',
#  'MLB19714192',
#  'MLB36205181',
#  'MLB38887046',
#  'MLB38580551',
#  'MLB38652768',
#  'MLB54497851',
#  'MLB62190038',
#  'MLB34233483',
#  'MLB21307953',
#  'MLB34064383',
#  'MLB27714646',
#  'MLB52688976',
#  'MLB27186156',
#  'MLB27392034',
#  'MLB45247937',
#  'MLB45132930',
#  'MLB54439058',
#  'MLB44770764',
#  'MLB35846739',
#  'MLB29340153',
#  'MLB27275775',
#  'MLB37704330',
#  'MLB32392708',
#  'MLB59687181',
#  'MLB48535063',
#  'MLB27552956',
#  'MLB27826637',
#  'MLB36143189',
#  'MLB27816336',
#  'MLB35241852',
#  'MLB48212136',
#  'MLB27108448',
#  'MLB27090138',
#  'MLB28688113',
#  'MLB27857072',
#  'MLB38423832',
#  'MLB27108443',
#  'MLB53547771',
#  'MLB48418106',
#  'MLB27352689',
#  'MLB29262471',
#  'MLB27222208',
#  'MLB53757234',
#  'MLB32645827',
#  'MLB49363451',
#  'MLB56483970',
#  'MLB37079958',
#  'MLB32309751',
#  'MLB30942930',
#  'MLB41156271',
#  'MLB53348803',
#  'MLB51916135',
#  'MLB43438722',
#  'MLB37231735',
#  'MLB39899873',
#  'MLB25389787',
#  'MLB35792356',
#  'MLB41177972',
#  'MLB22775619',
#  'MLB23206980',
#  'MLB35434187',
#  'MLB36257977',
#  'MLB22802101',
#  'MLB30483204',
#  'MLB35675293',
#  'MLB51294025',
#  'MLB39899797',
#  'MLB45439378',
#  'MLB35781221',
#  'MLB43289017',
#  'MLB40602817',
#  'MLB43970026',
#  'MLB43956120',
#  'MLB44591328',
#  'MLB39707800',
#  'MLB43349165',
#  'MLB39154577',
#  'MLB39970161',
#  'MLB39484104',
#  'MLB35936163',
#  'MLB42885512',
#  'MLB23206976',
#  'MLB41562018',
#  'MLB40274435',
#  'MLB39898295',
#  'MLB40053974',
#  'MLB40486157',
#  'MLB39914799',
#  'MLB35795312',
#  'MLB35681195',
#  'MLB44164357',
#  'MLB43293735',
#  'MLB42363143',
#  'MLB39484073',
#  'MLB39967816',
#  'MLB39977911',
#  'MLB35939583',
#  'MLB42949971',
#  'MLB41413438',
#  'MLB23050459',
#  'MLB44592394',
#  'MLB33851627',
#  'MLB35766321',
#  'MLB39686071',
#  'MLB44914235',
#  'MLB39484456',
#  'MLB46840442',
#  'MLB25133898',
#  'MLB35683185',
#  'MLB27271165',
#  'MLB22889809',
#  'MLB22969726',
#  'MLB59128214',
#  'MLB59142103',
#  'MLB26871392',
#  'MLB39993358',
#  'MLB25420291',
#  'MLB35438365',
#  'MLB23584161',
#  'MLB59133353',
#  'MLB41543740',
#  'MLB29377673',
#  'MLB35791795',
#  'MLB35807211',
#  'MLB35732391',
#  'MLB36031994',
#  'MLB26871336',
#  'MLB59131720',
#  'MLB24889788',
#  'MLB22611731',
#  'MLB34349486',
#  'MLB22490095',
#  'MLB24272639',
#  'MLB29793904',
#  'MLB28577248',
#  'MLB37231981',
#  'MLB42110824',
#  'MLB26720266',
#  'MLB34112780',
#  'MLB59173695',
#  'MLB23061216',
#  'MLB49673498',
#  'MLB37386277',
#  'MLB44411534',
#  'MLB58422238',
#  'MLB25766191',
#  'MLB22761042',
#  'MLB46189709',
#  'MLB27860038',
#  'MLB34090345',
#  'MLB27731746',
#  'MLB23013870',
#  'MLB23123808',
#  'MLB32101252',
#  'MLB42947569',
#  'MLB22511089',
#  'MLB61750715',
#  'MLB22663877',
#  'MLB24080500',
#  'MLB37847327',
#  'MLB37940759',
#  'MLB33953830',
#  'MLB25133273',
#  'MLB22695974',
#  'MLB27463021',
#  'MLB25132713',
#  'MLB23967456',
#  'MLB52833401',
#  'MLB45307178',
#  'MLB53785840',
#  'MLB41592496',
#  'MLB22948663',
#  'MLB22937488',
#  'MLB46469618',
#  'MLB23967462',
#  'MLB59017217',
#  'MLB30987129',
#  'MLB51035513',
#  'MLB23017518',
#  'MLB27789422',
#  'MLB23546136',
#  'MLB33324902',
#  'MLB29664922',
#  'MLB25132232',
#  'MLB34015194',
#  'MLB24517649',
#  'MLB22266345',
#  'MLB25254763',
#  'MLB36521938',
#  'MLB24764653',
#  'MLB32966982',
#  'MLB41773299',
#  'MLB23008208',
#  'MLB23066125',
#  'MLB48175377',
#  'MLB54037570',
#  'MLB45225132',
#  'MLB22621146',
#  'MLB30405525',
#  'MLB25132709',
#  'MLB42478187',
#  'MLB22652937',
#  'MLB23802064',
#  'MLB24155440',
#  'MLB32166497',
#  'MLB27794004',
#  'MLB22511210',
#  'MLB22969705',
#  'MLB22663880',
#  'MLB27861621',
#  'MLB43331566',
#  'MLB23483712',
#  'MLB27775752',
#  'MLB22663887',
#  'MLB26753386',
#  'MLB22775662',
#  'MLB29160420',
#  'MLB44993873',
#  'MLB59099585',
#  'MLB44895662',
#  'MLB29103826',
#  'MLB26890061',
#  'MLB55667052',
#  'MLB42340194',
#  'MLB24141002',
#  'MLB22737094',
#  'MLB22723564',
#  'MLB22490083',
#  'MLB22511212',
#  'MLB57509888',
#  'MLB29329227',
#  'MLB39099692',
#  'MLB28995159',
#  'MLB23791279',
#  'MLB22695975',
#  'MLB22642626',
#  'MLB29241465',
#  'MLB29605163',
#  'MLB39552201',
#  'MLB56136307',
#  'MLB57583331',
#  'MLB23558321',
#  'MLB47041820',
#  'MLB23491995',
#  'MLB39136702',
#  'MLB43173537',
#  'MLB39012030',
#  'MLB37193095',
#  'MLB56722450',
#  'MLB40167873',
#  'MLB22837726',
#  'MLB35733494',
#  'MLB25254603',
#  'MLB56951164',
#  'MLB36961829',
#  'MLB48873836',
#  'MLB23677291',
#  'MLB41949178',
#  'MLB50750469',
#  'MLB49860884',
#  'MLB39060468',
#  'MLB47354665',
#  'MLB37837157',
#  'MLB43487661',
#  'MLB48863277',
#  'MLB52339226',
#  'MLB37257397',
#  'MLB48828158',
#  'MLB27727909',
#  'MLB49777191',
#  'MLB36328550',
#  'MLB46493688',
#  'MLB48549721',
#  'MLB39373683',
#  'MLB47949397',
#  'MLB32382704',
#  'MLB48499238',
#  'MLB27736969',
#  'MLB23808449',
#  'MLB41922583',
#  'MLB48523160',
#  'MLB53784442',
#  'MLB38259713',
#  'MLB46405128',
#  'MLB48862301',
#  'MLB50501461',
#  'MLB38148092',
#  'MLB35477326',
#  'MLB60358348',
#  'MLB44897566',
#  'MLB34235844',
#  'MLB45233765',
#  'MLB37839021',
#  'MLB44011499',
#  'MLB36520489',
#  'MLB38605618',
#  'MLB60214512',
#  'MLB61406743',
#  'MLB55541609',
#  'MLB28903173',
#  'MLB48816455',
#  'MLB33058393',
#  'MLB60723803',
#  'MLB40835938',
#  'MLB48839982',
#  'MLB26109358',
#  'MLB19710232',
#  'MLB34019903',
#  'MLB24151143',
#  'MLB29338457',
#  'MLB47722710',
#  'MLB22881783',
#  'MLB23763180',
#  'MLB23763119',
#  'MLB45948244',
#  'MLB45673266',
#  'MLB34372642',
#  'MLB45809971',
#  'MLB42598978',
#  'MLB22538355',
#  'MLB21145178',
#  'MLB23427529',
#  'MLB26378343',
#  'MLB50871740',
#  'MLB21337390',
#  'MLB19756581',
#  'MLB20005141',
#  'MLB28698435',
#  'MLB22856639',
#  'MLB24804063',
#  'MLB26378230',
#  'MLB21294047',
#  'MLB21558707',
#  'MLB34265370',
#  'MLB25947151',
#  'MLB49826274',
#  'MLB44982092',
#  'MLB40872140',
#  'MLB47719836',
#  'MLB26833799',
#  'MLB39137726',
#  'MLB24253851',
#  'MLB34223388',
#  'MLB27094730',
#  'MLB35955259',
#  'MLB26969469',
#  'MLB25578380',
#  'MLB19712585',
#  'MLB24716223',
#  'MLB22906089',
#  'MLB34140626',
#  'MLB21788043',
#  'MLB26136006',
#  'MLB24113974',
#  'MLB23912654',
#  'MLB61692808',
#  'MLB25124238',
#  'MLB24455694',
#  'MLB36217437',
#  'MLB21720421',
#  'MLB33068830',
#  'MLB22892599',
#  'MLB26197089',
#  'MLB26515255',
#  'MLB29562367',
#  'MLB35099731',
#  'MLB26197091',
#  'MLB21692060',
#  'MLB21915289',
#  'MLB22811053',
#  'MLB37901877',
#  'MLB34226424',
#  'MLB19606370',
#  'MLB25482102',
#  'MLB25391995',
#  'MLB20466345',
#  'MLB23343912',
#  'MLB21492038',
#  'MLB25952240',
#  'MLB25952253',
#  'MLB21558714',
#  'MLB21835849',
#  'MLB51690865',
#  'MLB60069506',
#  'MLB25952326',
#  'MLB21024578',
#  'MLB25952304',
#  'MLB47725936',
#  'MLB20466414',
#  'MLB22305343',
#  'MLB24588422',
#  'MLB36212454',
#  'MLB26378271',
#  'MLB21340536',
#  'MLB54054526',
#  'MLB33035084',
#  'MLB21305484',
#  'MLB30607722',
#  'MLB24658989',
#  'MLB22828005',
#  'MLB23609972',
#  'MLB22958324',
#  'MLB25392005',
#  'MLB20656450',
#  'MLB25578372',
#  'MLB39259069',
#  'MLB22752934',
#  'MLB44200116',
#  'MLB25778606',
#  'MLB24608637',
#  'MLB21847224',
#  'MLB24658987',
#  'MLB30210386',
#  'MLB53179392',
#  'MLB42012409',
#  'MLB28865167',
#  'MLB27735313',
#  'MLB27719895',
#  'MLB48551326',
#  'MLB28482875',
#  'MLB42012430',
#  'MLB59597077',
#  'MLB38331556',
#  'MLB35845608',
#  'MLB50743901',
#  'MLB20537521',
#  'MLB42088380',
#  'MLB28534205',
#  'MLB27275433',
#  'MLB28799580',
#  'MLB38543311',
#  'MLB55015137',
#  'MLB56749080',
#  'MLB44633552',
#  'MLB36399376',
#  'MLB27541774',
#  'MLB52111569',
#  'MLB41952921',
#  'MLB52863501',
#  'MLB62254106',
#  'MLB28485496',
#  'MLB20537516',
#  'MLB52833376',
#  'MLB41991354',
#  'MLB27940330',
#  'MLB33975716',
#  'MLB36881566',
#  'MLB15458050',
#  'MLB40459880',
#  'MLB27733487',
#  'MLB20537515',
#  'MLB25212620',
#  'MLB36192207',
#  'MLB27736853',
#  'MLB49548155',
#  'MLB20484201',
#  'MLB32961480',
#  'MLB62239502',
#  'MLB38741525',
#  'MLB28373932',
#  'MLB28255295',
#  'MLB23255350',
#  'MLB60017513',
#  'MLB37237433',
#  'MLB27859843',
#  'MLB25212629',
#  'MLB48874958',
#  'MLB59777085',
#  'MLB59985416',
#  'MLB15469699',
#  'MLB30770355',
#  'MLB30393633',
#  'MLB42144224',
#  'MLB30096994',
#  'MLB43104744',
#  'MLB27699998',
#  'MLB21485117',
#  'MLB25824897',
#  'MLB50969230',
#  'MLB20537511',
#  'MLB48222869',
#  'MLB48459699',
#  'MLB28500550',
#  'MLB21346273',
#  'MLB48000325',
#  'MLB60012929',
#  'MLB27472599',
#  'MLB27547445',
#  'MLB29339841',
#  'MLB36852317',
#  'MLB28525716',
#  'MLB49886419',
#  'MLB49908715',
#  'MLB49918229',
#  'MLB41238009',
#  'MLB20517334',
#  'MLB32390745',
#  'MLB47944605',
#  'MLB59470423',
#  'MLB26837986',
#  'MLB61320315',
#  'MLB54822328',
#  'MLB28534224',
#  'MLB28512166',
#  'MLB38572679',
#  'MLB28836777',
#  'MLB25212628',
#  'MLB29057809',
#  'MLB27738417',
#  'MLB28473036',
#  'MLB23972473',
#  'MLB52137054',
#  'MLB47973704',
#  'MLB52854556',
#  'MLB41233866',
#  'MLB26316885',
#  'MLB28538938',
#  'MLB20537517',
#  'MLB28800423',
#  'MLB40698782',
#  'MLB28374112',
#  'MLB61741034',
#  'MLB61427328',
#  'MLB41981329',
#  'MLB48962228',
#  'MLB23077226',
#  'MLB54429846',
#  'MLB28476428',
#  'MLB49928876',
#  'MLB27975906',
#  'MLB28373831',
#  'MLB23480981',
#  'MLB22254114',
#  'MLB41236874',
#  'MLB48088563',
#  'MLB48294410',
#  'MLB48167643',
#  'MLB48913705',
#  'MLB25212635',
#  'MLB27545778',
#  'MLB27049620',
#  'MLB28371081',
#  'MLB39049325',
#  'MLB27552958',
#  'MLB30153156',
#  'MLB28650588',
#  'MLB28027552',
#  'MLB34280639',
#  'MLB32452188',
#  'MLB57493542',
#  'MLB27923664',
#  'MLB37814273',
#  'MLB49851124',
#  'MLB51913658',
#  'MLB29456447',
#  'MLB29099491',
#  'MLB32595992',
#  'MLB54900862',
#  'MLB61796963',
#  'MLB27505333',
#  'MLB28942822',
#  'MLB61678134',
#  'MLB33951054',
#  'MLB59553253',
#  'MLB40684093',
#  'MLB49983264',
#  'MLB45327421',
#  'MLB27632861',
#  'MLB29462846',
#  'MLB61658188',
#  'MLB60365723',
#  'MLB27536473',
#  'MLB61981524',
#  'MLB36274614',
#  'MLB44856922',
#  'MLB46275843',
#  'MLB42751333',
#  'MLB27753509',
#  'MLB27696759',
#  'MLB61118503',
#  'MLB34811390',
#  'MLB23883954',
#  'MLB61334901',
#  'MLB61335802',
#  'MLB36757007',
#  'MLB60530453',
#  'MLB37337301',
#  'MLB60285699',
#  'MLB42484214',
#  'MLB47590308',
#  'MLB29017989',
#  'MLB29629811',
#  'MLB61591641',
#  'MLB61982918',
#  'MLB59579916',
#  'MLB25804187',
#  'MLB36505335',
#  'MLB27716996',
#  'MLB32392962',
#  'MLB54211500',
#  'MLB27070882',
#  'MLB35952056',
#  'MLB27791831',
#  'MLB25345189',
#  'MLB27070881',
#  'MLB36070069',
#  'MLB52141265',
#  'MLB59684762',
#  'MLB27751836',
#  'MLB27631605',
#  'MLB44994733',
#  'MLB60238801',
#  'MLB42420814',
#  'MLB40679937',
#  'MLB40654542',
#  'MLB24795182',
#  'MLB23903660',
#  'MLB42982122',
#  'MLB40680370',
#  'MLB45873172',
#  'MLB28954607',
#  'MLB54262188',
#  'MLB42739681',
#  'MLB35513817',
#  'MLB48524616',
#  'MLB59652336',
#  'MLB37649671',
#  'MLB42808189',
#  'MLB26889701',
#  'MLB36044733',
#  'MLB25527027',
#  'MLB28933460',
#  'MLB25632565',
#  'MLB26889737',
#  'MLB40686404',
#  'MLB29710794',
#  'MLB27643223',
#  'MLB27495545',
#  'MLB47653355',
#  'MLB29371634',
#  'MLB61340046',
#  'MLB24601884',
#  'MLB41100765',
#  'MLB27526925',
#  'MLB54970860',
#  'MLB48917284',
#  'MLB35986262',
#  'MLB26889740',
#  'MLB42556355',
#  'MLB27227783',
#  'MLB31765781',
#  'MLB27782635',
#  'MLB35581376',
#  'MLB40060774',
#  'MLB25345202',
#  'MLB36144866',
#  'MLB25804192',
#  'MLB36538021',
#  'MLB32819327',
#  'MLB56433108',
#  'MLB23871295',
#  'MLB52845665',
#  'MLB35530004',
#  'MLB25527062',
#  'MLB25527080',
#  'MLB32688329',
#  'MLB25804191',
#  'MLB26375094',
#  'MLB24694027',
#  'MLB60853607',
#  'MLB29643573',
#  'MLB53617829',
#  'MLB29464725',
#  'MLB44203495',
#  'MLB53049225',
#  'MLB32440756',
#  'MLB37143172',
#  'MLB36381597',
#  'MLB28628160',
#  'MLB29359017',
#  'MLB38566655',
#  'MLB25527074',
#  'MLB35447011',
#  'MLB32449044',
#  'MLB28443634',
#  'MLB25794475',
#  'MLB32448295',
#  'MLB26889689',
#  'MLB57569985',
#  'MLB44870991',
#  'MLB32032566',
#  'MLB52863331',
#  'MLB28981287',
#  'MLB36357719',
#  'MLB41302832',
#  'MLB34035464',
#  'MLB56639217',
#  'MLB44977542',
#  'MLB35910960',
#  'MLB34591276',
#  'MLB45776894',
#  'MLB43495558',
#  'MLB49706219',
#  'MLB45794549',
#  'MLB52888596',
#  'MLB28946589',
#  'MLB39385584',
#  'MLB41822818',
#  'MLB44275206',
#  'MLB32627076',
#  'MLB42556459',
#  'MLB25716378',
#  'MLB39445684',
#  'MLB42734954',
#  'MLB26889727',
#  'MLB34137095',
#  'MLB41100893',
#  'MLB32381654',
#  'MLB61266052',
#  'MLB34853793',
#  'MLB62173818',
#  'MLB61444679',
#  'MLB47065738',
#  'MLB27708699',
#  'MLB42443229',
#  'MLB46159986',
#  'MLB42686657',
#  'MLB40759619',
#  'MLB29520407',
#  'MLB21925155',
#  'MLB24971238',
#  'MLB35412503',
#  'MLB25655635',
#  'MLB35336149',
#  'MLB49405920',
#  'MLB46662995',
#  'MLB28930016',
#  'MLB21718682',
#  'MLB21446708',
#  'MLB41996280',
#  'MLB21604324',
#  'MLB43507913',
#  'MLB28927417',
#  'MLB45687523',
#  'MLB28751058',
#  'MLB24971334',
#  'MLB34132099',
#  'MLB42151478',
#  'MLB33961390',
#  'MLB23836524',
#  'MLB45932804',
#  'MLB46002487',
#  'MLB56407149',
#  'MLB25369510',
#  'MLB52866256',
#  'MLB34810942',
#  'MLB23439133',
#  'MLB21885251',
#  'MLB23300175',
#  'MLB44147369',
#  'MLB21477902',
#  'MLB21642585',
#  'MLB33368771',
#  'MLB54343629',
#  'MLB57303578',
#  'MLB21695241',
#  'MLB48705460',
#  'MLB23858289',
#  'MLB25069431',
#  'MLB22237987',
#  'MLB39931956',
#  'MLB42189569',
#  'MLB30329321',
#  'MLB21958187',
#  'MLB45295319',
#  'MLB61760126',
#  'MLB22707667',
#  'MLB25556226',
#  'MLB21478051',
#  'MLB34258560',
#  'MLB23553113',
#  'MLB24282666',
#  'MLB23424369',
#  'MLB21703284',
#  'MLB21876634',
#  'MLB25969744',
#  'MLB21870150',
#  'MLB44849635',
#  'MLB21714688',
#  'MLB22856122',
#  'MLB21464332',
#  'MLB53397197',
#  'MLB61271037',
#  'MLB24873399',
#  'MLB35430763',
#  'MLB25719970',
#  'MLB21775769',
#  'MLB41432353',
#  'MLB48444560',
#  'MLB21604140',
#  'MLB23424292',
#  'MLB39032970',
#  'MLB62182513',
#  'MLB21483208',
#  'MLB21720857',
#  'MLB41521714',
#  'MLB21792068',
#  'MLB22128247',
#  'MLB22382016',
#  'MLB23162942',
#  'MLB21477996',
#  'MLB21303129',
#  'MLB21293520',
#  'MLB38009719',
#  'MLB45331586',
#  'MLB52125317',
#  'MLB35228362',
#  'MLB51398858',
#  'MLB21695188',
#  'MLB51865504',
#  'MLB21368789',
#  'MLB36648513',
#  'MLB44018106',
#  'MLB25880382',
#  'MLB50493660',
#  'MLB42955042',
#  'MLB43506427',
#  'MLB35602964',
#  'MLB21865322',
#  'MLB21847579',
#  'MLB21478080',
#  'MLB21641868',
#  'MLB22688696',
#  'MLB51923248',
#  'MLB35508718',
#  'MLB42175520',
#  'MLB48718657',
#  'MLB21510515',
#  'MLB36853147',
#  'MLB59173373',
#  'MLB25397031',
#  'MLB21293417',
#  'MLB39432090',
#  'MLB40160069',
#  'MLB39104101',
#  'MLB40231494',
#  'MLB39059328',
#  'MLB21482456',
#  'MLB22897252',
#  'MLB49750655',
#  'MLB45706954',
#  'MLB21293972',
#  'MLB37928308',
#  'MLB39009716',
#  'MLB43014319',
#  'MLB46350683',
#  'MLB57773424',
#  'MLB53973818',
#  'MLB40118409',
#  'MLB58045811',
#  'MLB21451786',
#  'MLB23021348',
#  'MLB42110382',
#  'MLB29009946',
#  'MLB23555531',
#  'MLB26790075',
#  'MLB22793767',
#  'MLB23021352',
#  'MLB50852344',
#  'MLB40153580',
#  'MLB22856084',
#  'MLB21635772',
#  'MLB25069552',
#  'MLB33974217',
#  'MLB35059181',
#  'MLB25564743',
#  'MLB21393519',
#  'MLB37252265',
#  'MLB21668005',
#  'MLB21604255',
#  'MLB28939341',
#  'MLB21695244',
#  'MLB43689484',
#  'MLB22876355',
#  'MLB41830188',
#  'MLB23619763',
#  'MLB23000148',
#  'MLB21303130',
#  'MLB39244617',
#  'MLB36362741',
#  'MLB37989131',
#  'MLB25457121',
#  'MLB23661952',
#  'MLB21312681',
#  'MLB37033511',
#  'MLB46671831',
#  'MLB21673573',
#  'MLB21838424',
#  'MLB21948697',
#  'MLB34705107',
#  'MLB35369173',
#  'MLB22794852',
#  'MLB21884211',
#  'MLB35563269',
#  'MLB38063449',
#  'MLB21798890',
#  'MLB21293131',
#  'MLB24520922',
#  'MLB61750853',
#  'MLB35517817',
#  'MLB52857680',
#  'MLB35577210',
#  'MLB36050923',
#  ...]

# %%
avaliacoes = pd.read_csv("avaliacoes_limpo.csv")
perguntas = pd.read_csv("perguntas_limpo.csv")

# %%
smartObjectsReviews = ( avaliacoes[avaliacoes["id"].isin(smartObjects)]
                       .drop_duplicates()
                       .reset_index(drop=True)
                       .dropna() )
smartObjectsReviews
# Out:
#                                                   texto nota           id  \
# 0                              E muito prático. Gostei.    5  MLB36333923
# 1                               Ajuda muito em viagens.    5  MLB36333923
# 2                                            Muito top.    5  MLB36333923
# 3     Me atende produto muito bom bom para o que pre...    5  MLB36333923
# 4                                    Gostei muito 👏👏👏👏.    5  MLB36333923
# ...                                                 ...  ...          ...
# 2602  Atendeu super bem para controles de ventilador...    5  MLB50911897
# 2603              Produto excelente e facil instalacao.    5  MLB50911897
# 2604  Simples, rápido e eficiente. Produto muito bom...    5  MLB50911897
# 2605  É elogiado por sua facilidade de configuração ...    5  MLB50911897
# 2606  O produto cumpre o que promete possui um bom a...    5  MLB50911897
#
#               data
# 0     13 dez. 2024
# 1     16 jan. 2025
# 2     29 mar. 2025
# 3     08 mai. 2025
# 4     24 jul. 2025
# ...            ...
# 2602  28 nov. 2025
# 2603  01 dez. 2025
# 2604  25 out. 2025
# 2605  20 nov. 2025
# 2606  16 out. 2025
#
# [2535 rows x 4 columns]

# %%
smartObjectsQuestions = (perguntas[perguntas["id"].isin(smartObjects)]
                         .drop_duplicates()
                         .reset_index(drop=True))
smartObjectsQuestions
# Out:
#                                                pergunta  \
# 0                              Qual tamanho do cabo 12V
# 1                             Ela não congela só esfria
# 2     Boa tarde Estou precisando de duas placas , pr...
# 3     Tem o link só do cabo de alimentação dessa mes...
# 4     Boa tarde preciso da 220 mas somente a 110 est...
# ...                                                 ...
# 7688  Olá Consigo espelhar a tela do notebook sem pr...
# 7689  Eu consigo com esse aparelho por SBT Globo Rec...
# 7690      Este relógio funciona conectado com o celular
# 7691                    Posso aparelhar ele com celular
# 7692                 Boa noite! Ela serve como camera ?
#
#                                                resposta           id  \
# 0                          Olá, boa tarde! Cerca de 2M!  MLB36333923
# 1     Olá, boa tarde! Isso, ela é uma geladeira, dif...  MLB36333923
# 2     Olá, bom dia! Infelizmente não temos peças de ...  MLB36333923
# 3     Olá boa noite, No momento não temos estoque so...  MLB36333923
# 4     Oi, Luiz acurcio Abreu! Tudo bem? Neste anúnci...  MLB54448099
# ...                                                 ...          ...
# 7688  Boa tarde! Tudo bem? Sim, consegue sem precisa...  MLB28095709
# 7689  Boa noite! Tudo bem? Sim, com esse aparelho vo...  MLB28095709
# 7690  Boa tarde caro cliente. Sim, o smartwatch Ultr...  MLB28877830
# 7691  Boa tarde caro cliente. Sim, o smartwatch Ultr...  MLB28877830
# 7692  Olá, boa noite. Sim, você consegue acessar a c...  MLB43670109
#
#             data
# 0     28/08/2025
# 1     15/07/2025
# 2     14/07/2025
# 3     12/07/2025
# 4     13/11/2025
# ...          ...
# 7688  08/10/2025
# 7689  10/06/2025
# 7690  21/11/2025
# 7691  21/11/2025
# 7692  04/05/2025
#
# [7693 rows x 4 columns]

# %%
produtos = pd.read_csv("produtos_limpo.csv")
produtos = produtos[produtos["id"].isin(smartObjects)].drop_duplicates().reset_index(drop=True) 
produtos
# Out:
#                id          date_created catalog_product_id          domain_id  \
# 0     MLB36333923  2024-04-30T07:10:59Z        MLB36333923  MLB-REFRIGERATORS
# 1     MLB36139109  2024-04-24T00:05:50Z        MLB36139109  MLB-REFRIGERATORS
# 2     MLB21345002  2023-01-25T11:36:55Z        MLB21345002  MLB-REFRIGERATORS
# 3     MLB38703841  2024-07-29T00:19:00Z        MLB38703841  MLB-REFRIGERATORS
# 4     MLB36398531  2024-04-30T22:21:23Z        MLB36398531  MLB-REFRIGERATORS
# ...           ...                   ...                ...                ...
# 4292  MLB53221956  2025-08-01T19:02:38Z        MLB53221956        MLB-DIMMERS
# 4293  MLB36376467  2024-04-30T19:45:28Z        MLB36376467        MLB-DIMMERS
# 4294  MLB38661265  2024-07-26T15:27:49Z        MLB38661265        MLB-DIMMERS
# 4295  MLB38765729  2024-07-31T01:39:07Z        MLB38765729        MLB-DIMMERS
# 4296  MLB39454456  2024-08-22T19:56:27Z        MLB39454456        MLB-DIMMERS
#
#                                                    name main_features  \
# 0                Geladeira Portátil Automotiva Cfx335 E            []
# 1          Geladeira Portátil Automotiva Cfx345 12v/24v            []
# 2                   Geladeira LG LS66sdp No Frost 617lt            []
# 3     Geladeira Duplex Inverse Evolution Smartthings...            []
# 4       Geladeira Inverter Auto Defrost LG Freezer 451l            []
# ...                                                 ...           ...
# 4292  Interruptor Wifi Inteligente Vênus 1 Botão Vid...            []
# 4293  Interruptor Inteligente Zigbee 4x2 1 Tecla Fís...            []
# 4294  Interruptor Inteligente Wi-Fi para Ventilador ...            []
# 4295  Interruptor inteligente Wi-Fi para ventilador ...            []
# 4296  Interruptor Inteligente Wi-fi Com Função Dimme...            []
#
#      quality_type priority     type  \
# 0        COMPLETE   MEDIUM  PRODUCT
# 1        COMPLETE   MEDIUM  PRODUCT
# 2        COMPLETE   MEDIUM  PRODUCT
# 3        COMPLETE   MEDIUM  PRODUCT
# 4        COMPLETE   MEDIUM  PRODUCT
# ...           ...      ...      ...
# 4292     COMPLETE   MEDIUM  PRODUCT
# 4293     COMPLETE   MEDIUM  PRODUCT
# 4294     COMPLETE   MEDIUM  PRODUCT
# 4295     COMPLETE   MEDIUM  PRODUCT
# 4296     COMPLETE   MEDIUM  PRODUCT
#
#                                                keywords  description
# 0                Geladeira Portátil Automotiva Cfx335 E          NaN
# 1          Geladeira Portátil Automotiva Cfx345 12v/24v          NaN
# 2                   Geladeira LG LS66sdp No Frost 617lt          NaN
# 3     Geladeira Duplex Inverse Evolution Smartthings...          NaN
# 4       Geladeira Inverter Auto Defrost LG Freezer 451l          NaN
# ...                                                 ...          ...
# 4292  Interruptor Wifi Inteligente Vênus 1 Botão Vid...          NaN
# 4293  Interruptor Inteligente Zigbee 4x2 1 Tecla Fís...          NaN
# 4294  Interruptor Inteligente Wi-Fi para Ventilador ...          NaN
# 4295  Interruptor inteligente Wi-Fi para ventilador ...          NaN
# 4296  Interruptor Inteligente Wi-fi Com Função Dimme...          NaN
#
# [4297 rows x 11 columns]

# %%
# função de remoção de stopwords
def removerstopwords(texto):
    # deixando texto em minúsculo
    texto = texto.lower()

    # removendo pontuações do texto
    pontuacao = str.maketrans('', '', string.punctuation)
    texto = texto.translate(pontuacao)

    # removendo stopwords do texto
    palavras = word_tokenize(texto, language='portuguese')
    stopwaords = set(stopwords.words('portuguese'))
    palavrasfiltradas = [palavra for palavra in palavras if palavra.lower() not in stopwaords]

    # removendo espaços vazios restantes dos tokens
    listasemvazios = list(filter(None, palavrasfiltradas))

    return listasemvazios

# %%
smartObjectsQuestions['perguntaFiltrado'] = smartObjectsQuestions['pergunta'].apply(removerstopwords)
smartObjectsQuestions['respostaFiltrado'] = smartObjectsQuestions['resposta'].apply(removerstopwords)
smartObjectsQuestions
# Out:
#                                                pergunta  \
# 0                              Qual tamanho do cabo 12V
# 1                             Ela não congela só esfria
# 2     Boa tarde Estou precisando de duas placas , pr...
# 3     Tem o link só do cabo de alimentação dessa mes...
# 4     Boa tarde preciso da 220 mas somente a 110 est...
# ...                                                 ...
# 7688  Olá Consigo espelhar a tela do notebook sem pr...
# 7689  Eu consigo com esse aparelho por SBT Globo Rec...
# 7690      Este relógio funciona conectado com o celular
# 7691                    Posso aparelhar ele com celular
# 7692                 Boa noite! Ela serve como camera ?
#
#                                                resposta           id  \
# 0                          Olá, boa tarde! Cerca de 2M!  MLB36333923
# 1     Olá, boa tarde! Isso, ela é uma geladeira, dif...  MLB36333923
# 2     Olá, bom dia! Infelizmente não temos peças de ...  MLB36333923
# 3     Olá boa noite, No momento não temos estoque so...  MLB36333923
# 4     Oi, Luiz acurcio Abreu! Tudo bem? Neste anúnci...  MLB54448099
# ...                                                 ...          ...
# 7688  Boa tarde! Tudo bem? Sim, consegue sem precisa...  MLB28095709
# 7689  Boa noite! Tudo bem? Sim, com esse aparelho vo...  MLB28095709
# 7690  Boa tarde caro cliente. Sim, o smartwatch Ultr...  MLB28877830
# 7691  Boa tarde caro cliente. Sim, o smartwatch Ultr...  MLB28877830
# 7692  Olá, boa noite. Sim, você consegue acessar a c...  MLB43670109
#
#             data                                   perguntaFiltrado  \
# 0     28/08/2025                               [tamanho, cabo, 12v]
# 1     15/07/2025                                  [congela, esfria]
# 2     14/07/2025  [boa, tarde, precisando, duas, placas, pra, po...
# 3     12/07/2025  [link, cabo, alimentação, dessa, mesma, gelade...
# 4     13/11/2025  [boa, tarde, preciso, 220, somente, 110, frete...
# ...          ...                                                ...
# 7688  08/10/2025  [olá, consigo, espelhar, tela, notebook, preci...
# 7689  10/06/2025  [consigo, aparelho, sbt, globo, record, band, ...
# 7690  21/11/2025            [relógio, funciona, conectado, celular]
# 7691  21/11/2025                        [posso, aparelhar, celular]
# 7692  04/05/2025                        [boa, noite, serve, camera]
#
#                                        respostaFiltrado
# 0                          [olá, boa, tarde, cerca, 2m]
# 1      [olá, boa, tarde, geladeira, diferente, freezer]
# 2     [olá, bom, dia, infelizmente, peças, reposição...
# 3     [olá, boa, noite, momento, estoque, somente, c...
# 4     [oi, luiz, acurcio, abreu, tudo, bem, neste, a...
# ...                                                 ...
# 7688  [boa, tarde, tudo, bem, sim, consegue, precisa...
# 7689  [boa, noite, tudo, bem, sim, aparelho, consegu...
# 7690  [boa, tarde, caro, cliente, sim, smartwatch, u...
# 7691  [boa, tarde, caro, cliente, sim, smartwatch, u...
# 7692  [olá, boa, noite, sim, consegue, acessar, câme...
#
# [7693 rows x 6 columns]

# %%
# chamando função
smartObjectsReviews['textofiltrado'] = smartObjectsReviews['texto'].apply(removerstopwords)
smartObjectsReviews
# Out:
#                                                   texto nota           id  \
# 0                              E muito prático. Gostei.    5  MLB36333923
# 1                               Ajuda muito em viagens.    5  MLB36333923
# 2                                            Muito top.    5  MLB36333923
# 3     Me atende produto muito bom bom para o que pre...    5  MLB36333923
# 4                                    Gostei muito 👏👏👏👏.    5  MLB36333923
# ...                                                 ...  ...          ...
# 2602  Atendeu super bem para controles de ventilador...    5  MLB50911897
# 2603              Produto excelente e facil instalacao.    5  MLB50911897
# 2604  Simples, rápido e eficiente. Produto muito bom...    5  MLB50911897
# 2605  É elogiado por sua facilidade de configuração ...    5  MLB50911897
# 2606  O produto cumpre o que promete possui um bom a...    5  MLB50911897
#
#               data                                      textofiltrado
# 0     13 dez. 2024                                  [prático, gostei]
# 1     16 jan. 2025                                   [ajuda, viagens]
# 2     29 mar. 2025                                              [top]
# 3     08 mai. 2025   [atende, produto, bom, bom, preciso, satisfeito]
# 4     24 jul. 2025                                     [gostei, 👏👏👏👏]
# ...            ...                                                ...
# 2602  28 nov. 2025  [atendeu, super, bem, controles, ventilador, t...
# 2603  01 dez. 2025            [produto, excelente, facil, instalacao]
# 2604  25 out. 2025  [simples, rápido, eficiente, produto, bom, tes...
# 2605  20 nov. 2025  [elogiado, facilidade, configuração, alcance, ...
# 2606  16 out. 2025  [produto, cumpre, promete, possui, bom, acabam...
#
# [2535 rows x 5 columns]

# %%
# import para gerar a nuvem de palavras


# função para gerar wordcloud
def nuvempalavrasgerar(texto, nome, colors):
    palavraschave = set(stopwords.words(['portuguese', 'english']))

    mask = np.array(Image.open("imagemNuvem.png"))

    # inicializa uma word cloud
    wordcloud = WordCloud(stopwords = palavraschave,
                          background_color = 'white', # cor de fundo
                          width = 2000, # largura
                          height = 1200, # altura
                          colormap  = colors,
                          mask=mask) # cores das palavras

    wordcloud.generate(str(texto))
    plt.figure(figsize = (5, 5)) # tamanho do gráfico
    plt.imshow(wordcloud) # plotagem da nuvem de palavras
    plt.axis('off') # remove as bordas
    plt.show() # mostra a word cloud
    wordcloud.to_file(nome+'.png')

# %%
# preparar dados para o worcloud
smartObjectsReviews['textoFiltradoJunto'] = smartObjectsReviews['textofiltrado'].str.join(', ')
texto = " ".join(s for s in smartObjectsReviews['textoFiltradoJunto'])
texto = texto.replace('além', '')
texto = texto.replace('disso', '')
texto = texto.replace('produto', '')

# chamando a função
nuvempalavrasgerar(texto, "smartObjectsReviews3", 'copper_r')

# %%
smartObjectsQuestions["perguntaFiltradoJunto"] = smartObjectsQuestions["perguntaFiltrado"].str.join(', ')
smartObjectsQuestions["respostaFiltradoJunto"] = smartObjectsQuestions["respostaFiltrado"].str.join(', ')

texto_perguntas = " ".join(s for s in smartObjectsQuestions['perguntaFiltradoJunto'])
texto_perguntas = texto_perguntas.replace("bom, dia", "")
texto_perguntas = texto_perguntas.replace("boa, tarde", "")
texto_perguntas = texto_perguntas.replace("boa, noite", "")
texto_perguntas = texto_perguntas.replace("olá", "")
texto_perguntas = texto_perguntas.replace("ola", "")
texto_perguntas = texto_perguntas.replace("tudo, bem", "")
texto_perguntas = texto_perguntas.replace("vc", "")
texto_perguntas = texto_perguntas.replace("pra", "")

texto_respostas = " ".join(s for s in smartObjectsQuestions['respostaFiltradoJunto'])
texto_respostas = texto_respostas.replace("olá, tudo", "")
texto_respostas = texto_respostas.replace("tudo, bem", "")
texto_respostas = texto_respostas.replace("olá", "")
texto_respostas = texto_respostas.replace("boa, tarde", "")
texto_respostas = texto_respostas.replace("bom, dia", "")
texto_respostas = texto_respostas.replace("boa, noite", "")
texto_respostas = texto_respostas.replace("vc", "")
texto_respostas = texto_respostas.replace("pra", "")

nuvempalavrasgerar(texto_perguntas, "smartObjectsPerguntas3", 'copper_r')
nuvempalavrasgerar(texto_respostas, "smartObjectsRespostas3", 'copper_r')

# %%
def analisesentimentosBlob(texto):
  # Cria o objeto TextBlob
  blob = TextBlob(texto)

  # Pega o sentimento
  # se > 0.1 é positivo, se 0 é neutro e se < -0.1 é negativo
  sentimento = blob.sentiment
  return sentimento.polarity

def analisesentimentosLeIA(texto):
  # Cria o objeto LeIA
  s = SentimentIntensityAnalyzer()


  # Pega o sentimento
  # se > 0.05 é positivo, entre é neutro e se < -0.05 é negativo
  sentimento = s.polarity_scores(texto)
  return sentimento["compound"]

# %%
# gerando dados
smartObjectsReviews['sentimento'] = smartObjectsReviews['texto'].apply(analisesentimentosLeIA)
smartObjectsReviews

# %%
smartObjectsQuestions['sentimento'] = smartObjectsQuestions["pergunta"].apply(analisesentimentosLeIA)
smartObjectsQuestions
# Out:
#                                                 pergunta  \
# 0                               Qual tamanho do cabo 12V
# 1                              Ela não congela só esfria
# 2      Boa tarde Estou precisando de duas placas , pr...
# 3      Tem o link só do cabo de alimentação dessa mes...
# 4      Boa tarde preciso da 220 mas somente a 110 est...
# ...                                                  ...
# 14640  Olá vendedor, a lâmpada é compatível com rede ...
# 14641                                    É 127v ou 220v?
# 14642                   Posso sintonizar a cor pelo app?
# 14643              Olá, consigo deixar sempre no branco?
# 14644                 Boa noite! Ela serve como camera ?
#
#                                                 resposta           id  \
# 0                           Olá, boa tarde! Cerca de 2M!  MLB36333923
# 1      Olá, boa tarde! Isso, ela é uma geladeira, dif...  MLB36333923
# 2      Olá, bom dia! Infelizmente não temos peças de ...  MLB36333923
# 3      Olá boa noite, No momento não temos estoque so...  MLB36333923
# 4      Oi, Luiz acurcio Abreu! Tudo bem? Neste anúnci...  MLB54448099
# ...                                                  ...          ...
# 14640  Olá, A lâmpada Xiaomi Inteligente Wifi Smart L...  MLB37232290
# 14641  Boa tarde, agradecemos pelo contato! Ela é biv...  MLB43919988
# 14642  Boa tarde, agradecemos pelo contato! Sim, pelo...  MLB43919988
# 14643  É só altera de cor pelo aplicativo, a última c...  MLB43919988
# 14644  Olá, boa noite. Sim, você consegue acessar a c...  MLB43670109
#
#              data  sentimento
# 0      28/08/2025      0.0000
# 1      15/07/2025     -0.3182
# 2      14/07/2025      0.6036
# 3      12/07/2025      0.0000
# 4      13/11/2025      0.0129
# ...           ...         ...
# 14640  02/12/2025      0.0000
# 14641  10/11/2025      0.0000
# 14642  10/11/2025      0.0000
# 14643  30/05/2025      0.0000
# 14644  04/05/2025      0.4926
#
# [14645 rows x 5 columns]

# %%
# função de avaliação final
def tiposentimento(x):
  if x > 0.05:
    return 'Positivo'
  if x < -0.05:
    return 'Negativo'
  else:
    return 'Neutro'

# %%
smartObjectsQuestions['tiposentimento'] = smartObjectsQuestions['sentimento'].apply(tiposentimento)
smartObjectsQuestions['tiposentimento'].value_counts()
# Out:
# tiposentimento
# Neutro      6794
# Positivo    4869
# Negativo    2982
# Name: count, dtype: int64

# %%
# chamando a geração 
smartObjectsReviews['tiposentimento'] = smartObjectsReviews['sentimento'].apply(tiposentimento)

smartObjectsReviews['tiposentimento'].value_counts()
# Out:
# tiposentimento
# Positivo    3046
# Neutro       641
# Negativo     409
# Name: count, dtype: int64

# %%
smartObjectsReviews["nota"].value_counts()
# Out:
# nota
# 5       2263
# 4        191
# 1         47
# 3         21
# 2         12
# out.       1
# Name: count, dtype: int64

# %%
reviews_ruins = smartObjectsReviews[(smartObjectsReviews['tiposentimento'] != 'Positivo') & (smartObjectsReviews["nota"] <= '3')].reset_index(drop=True) 
reviews_ruins['textofiltrado'] = reviews_ruins['textofiltrado'].str.join(', ')
texto = " ".join(s for s in reviews_ruins['textofiltrado'])

texto = texto.replace('produto', '')
texto = texto.replace('pra', '')
texto = texto.replace('quer', '')
texto = texto.replace('nootbok', '')

nuvempalavrasgerar(texto, "reviews_ruins", 'copper_r')
